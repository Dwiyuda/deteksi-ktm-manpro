# %%
import torch
import torchvision
import matplotlib.pyplot as plt

print("PyTorch Version:", torch.__version__)
print("Torchvision Version:", torchvision.__version__)

# Cek apakah EfficientNet tersedia
try:
    from torchvision.models import efficientnet_b0
    model = efficientnet_b0(pretrained=True)
    print("✅ SUKSES: EfficientNet-B0 siap digunakan!")
except ImportError:
    print("❌ ERROR: Torchvision perlu diupdate.")
# Out:
# PyTorch Version: 2.9.1+cpu
# Torchvision Version: 0.24.1+cpu
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to C:\Users\TUF/.cache\torch\hub\checkpoints\efficientnet_b0_rwightman-7f5810bc.pth
# c:\Users\TUF\Downloads\tes.ipynb\venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\TUF\Downloads\tes.ipynb\venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100.0%
# ✅ SUKSES: EfficientNet-B0 siap digunakan!
